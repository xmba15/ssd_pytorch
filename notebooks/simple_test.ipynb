# %%
from __future__ import print_function
import os
import sys
import cv2
from matplotlib import pyplot as plt


from local_config import CURRENT_DIR
sys.path.append(os.path.join(CURRENT_DIR, ".."))
from config import Config

dt_config = Config()

# %% [markdown]
# # UEC FOOD Dataset

# %%
from data_loader import UecFoodDataset, UecFoodDataTransform

idx = 0

# %%
dataset = UecFoodDataset(data_path = dt_config.DATA_PATH)
image = dataset.visualize_one_image(idx)

plt.figure(figsize=(20, 20))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
idx += 1000

# %% [markdown]
# ## test augmentation

# %%
idx = 0

# %%
from albumentations import (
    BboxParams,
    HorizontalFlip,
    VerticalFlip,
    Resize,
    CenterCrop,
    RandomCrop,
    Crop,
    Compose
)

data_transform = UecFoodDataTransform(transforms=[VerticalFlip(p=1)], input_size=None, normalize=False)

dataset = UecFoodDataset(data_path = dt_config.DATA_PATH, transform=data_transform)
image = dataset.visualize_one_image(idx)

plt.figure(figsize=(20, 20))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
idx += 1000

# %% [markdown]
# # VOC dataset

# %%
from data_loader import VOCDataset

idx = 0

# %%
voc_dataset = VOCDataset(data_path = dt_config.DATA_PATH)

# %%
image = voc_dataset.visualize_one_image(idx)

plt.figure(figsize=(20, 20))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
idx += 100

# %%
len(voc_dataset)
# Out:
# 2501

# %%
voc_dataset.num_classes
# Out:
# 20

# %% [markdown]
# # Bird Dataset

# %%
from data_loader import BirdDataset

idx = 0

# %%
bird_dataset = BirdDataset(data_path = dt_config.DATA_PATH)

# %%
image = bird_dataset.visualize_one_image(idx)

plt.figure(figsize=(20, 20))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
idx += 5
